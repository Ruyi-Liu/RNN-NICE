# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
import time
import tracemalloc
import os

# Define the model classes (same as before)
class RNNCausalModel(nn.Module):
    def __init__(self, covariate_dim, treatment_dim, hidden_dim, output_dim, num_layers=2, dropout_prob=0.0):
        super(RNNCausalModel, self).__init__()
        self.covariate_dim = covariate_dim
        self.treatment_dim = treatment_dim
        self.hidden_dim = hidden_dim
        
        # RNN to process the sequence
        self.rnn = nn.GRU(
            input_size=covariate_dim + treatment_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout_prob if num_layers > 1 else 0
        )
        
        # Prediction network
        self.output_net = nn.Sequential(
            nn.Linear(hidden_dim + covariate_dim + 3 * treatment_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout_prob),
            nn.Linear(hidden_dim, output_dim)
        )
        
        # Network for intermediate predictions
        self.covariate_pred = nn.Sequential(
            nn.Linear(hidden_dim + treatment_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, covariate_dim)
        )
    def forward(self, X_seq, A_seq, predict_sequence=False):
        batch_size = X_seq.size(0)
        
        # Ensure treatments have correct dimensions [batch, seq_len, treatment_dim]
        if A_seq.dim() == 2:  # If shape is [batch, 3]
            A_seq = A_seq.unsqueeze(-1)  # Shape becomes [batch, 3, 1]
        elif A_seq.dim() == 3 and A_seq.size(-1) != self.treatment_dim:
            A_seq = A_seq.view(batch_size, -1, self.treatment_dim)
        
        # Combine covariates and treatments
        rnn_input = torch.cat([X_seq, A_seq], dim=-1)  # Shape: [batch, 3, covariate_dim + treatment_dim]
        
        # Initialize hidden state
        h0 = torch.zeros(self.rnn.num_layers, batch_size, self.hidden_dim).to(X_seq.device)
        
        # RNN forward pass
        rnn_out, _ = self.rnn(rnn_input, h0)  # rnn_out: [batch, 3, hidden_dim]
        
        # Final prediction components
        final_hidden = rnn_out[:, -1, :]  # Last time step
        X0 = X_seq[:, 0, :]  # Baseline covariates
        A_all = A_seq.view(batch_size, -1)  # Flatten treatments [batch, 3*treatment_dim]
        
        # Final prediction
        y_pred = self.output_net(torch.cat([final_hidden, X0, A_all], dim=-1))
        
        if predict_sequence:
            # Predict intermediate covariates
            X_preds = []
            for t in range(A_seq.size(1)):
                X_next = self.covariate_pred(torch.cat([rnn_out[:, t, :], A_seq[:, t, :]], dim=-1))
                X_preds.append(X_next)
            return y_pred, torch.stack(X_preds, dim=1)
        
        return y_pred

def train_rnn_model(model, train_loader, val_loader, num_epochs=50, learning_rate=0.01):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    criterion = nn.MSELoss(reduction='none')
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-3)
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        
        for X_batch, A_batch, weights_batch, y_batch in train_loader:
            # Move data to device
            X_batch = X_batch.to(device)
            A_batch = A_batch.to(device)
            weights_batch = weights_batch.to(device)
            y_batch = y_batch.to(device)
            
            optimizer.zero_grad()

            # Forward pass
            y_pred, X_preds = model(X_batch, A_batch, predict_sequence=True)
            
            # Compute losses
            loss_y = criterion(y_pred, y_batch)
            
            # Compare ALL predicted covariates (X_preds) with ALL actual covariates (X_batch)
            loss_X = criterion(X_preds, X_batch)  # Now comparing [batch, 3, 4] with [batch, 3, 4]
            # Option 1: Sum over both time and covariate dimensions (returns [500])
            loss_X_sum = loss_X.sum(dim=[1, 2])  # Shape: [500]

            # Option 2: Average over both dimensions (returns [500])
            loss_X_mean = loss_X.mean(dim=[1, 2])  # Shape: [500]

            # If you specifically need [500, 1], add an extra dimension
            loss_X_final = loss_X.sum(dim=[1, 2]).unsqueeze(1)  # Shape: [500, 1]
            # Weighted total loss
            total_loss = torch.mean(weights_batch * (loss_y + 0.5 * loss_X_final))
            total_loss.backward()
            optimizer.step()
            
            train_loss += total_loss.item()
        
        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, A_batch, weights_batch, y_batch in val_loader:
                X_batch, A_batch = X_batch.to(device), A_batch.to(device)
                weights_batch, y_batch = weights_batch.to(device), y_batch.to(device)
                
                y_pred = model(X_batch, A_batch)
                val_loss += torch.mean(weights_batch * criterion(y_pred, y_batch)).item()
        
        # print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss/len(train_loader):.4f}, Val Loss: {val_loss/len(val_loader):.4f}")
    
    return model


def estimate_rnn_causal_effect(model, X_val, A_val, treatment_pattern=[1,1,1]):
    """Estimate the average causal effect of Y(0,0,1) - Y(0,0,0)"""
    model.eval()
    device = next(model.parameters()).device
    
    # Create counterfactual treatment vectors with proper dimensions
    A_treatment = torch.tensor(treatment_pattern, dtype=torch.float32).view(1, 3, 1).to(device)
    A_control = torch.zeros(1, 3, 1).to(device)  # Shape: [1, 3, 1]
    
    y_treatment_list = []
    y_control_list = []
    
    with torch.no_grad():
        for X_sample in X_val:
            X_sample = X_sample.unsqueeze(0).to(device)  # Shape: [1, 3, 4]
            
            # Predict for both treatment scenarios
            y_treatment = model(X_sample, A_treatment)
            y_control = model(X_sample, A_control)
            
            y_treatment_list.append(y_treatment.item())
            y_control_list.append(y_control.item())
    
    # Compute average causal effect
    y_treatment = np.array(y_treatment_list)
    y_control = np.array(y_control_list)
    causal_effect = y_treatment - y_control
    average_causal_effect = np.mean(causal_effect)
    
    return average_causal_effect

from sklearn.linear_model import LogisticRegression

def process_single_file(file_path):
    """Process a single data file with logistic regression-based weights"""
    # Load and preprocess data
    data = pd.read_csv(file_path)
    y = data["Y_glomerular_filtration"].values
    treatments = data[["treatment_1", "treatment_2", "treatment_3"]].values
    covariates = data.drop(columns=["Y_glomerular_filtration", "treatment_1", "treatment_2", "treatment_3", 
                                  "ps_treatment_1", "ps_treatment_2", "ps_treatment_3"]).values
    covariates = covariates.reshape(-1, 3, 4)  # Shape: (n_samples, 3, 4)
    
    # Split data
    X_train, X_val, y_train, y_val, A_train, A_val, _, _ = train_test_split(
        covariates, y, treatments, np.zeros_like(treatments), test_size=0.05, random_state=42)
    
    # Convert to numpy arrays
    X_train_np = X_train.numpy() if torch.is_tensor(X_train) else X_train
    A_train_np = A_train.numpy() if torch.is_tensor(A_train) else A_train
    X_val_np = X_val.numpy() if torch.is_tensor(X_val) else X_val
    A_val_np = A_val.numpy() if torch.is_tensor(A_val) else A_val
    
    # Calculate marginal probabilities
    p_A1 = A_train_np[:, 0].mean()
    p_A2 = A_train_np[:, 1].mean()
    p_A3 = A_train_np[:, 2].mean()
    
    # Fit logistic models for each time point
    def get_weights(X, A, p_marginal):
        weights = []
        
        # Time point 1: P(A1|X1)
        X1 = X[:, 0, :]
        model1 = LogisticRegression().fit(X1, A[:, 0])
        pred1 = model1.predict_proba(X1)[:, 1]
        w1 = np.where(A[:, 0] == 1, p_marginal[0]/pred1, (1-p_marginal[0])/(1-pred1))
        weights.append(w1)
        
        # Time point 2: P(A2|X1,A1,X2)
        X2_features = np.concatenate([X[:, 0, :], A[:, 0:1], X[:, 1, :]], axis=1)
        model2 = LogisticRegression().fit(X2_features, A[:, 1])
        pred2 = model2.predict_proba(X2_features)[:, 1]
        w2 = np.where(A[:, 1] == 1, p_marginal[1]/pred2, (1-p_marginal[1])/(1-pred2))
        weights.append(w2)
        
        # Time point 3: P(A3|X1,A1,X2,A2,X3)
        X3_features = np.concatenate([X[:, 0, :], A[:, 0:1], X[:, 1, :], 
                                    A[:, 1:2], X[:, 2, :]], axis=1)
        model3 = LogisticRegression().fit(X3_features, A[:, 2])
        pred3 = model3.predict_proba(X3_features)[:, 1]
        w3 = np.where(A[:, 2] == 1, p_marginal[2]/pred3, (1-p_marginal[2])/(1-pred3))
        weights.append(w3)
        
        return np.prod(weights, axis=0)
    
    # Calculate weights
    combined_weight_train = get_weights(X_train_np, A_train_np, [p_A1, p_A2, p_A3])
    combined_weight_val = get_weights(X_val_np, A_val_np, [p_A1, p_A2, p_A3])
    
    # Convert to tensors
    X_train = torch.tensor(X_train_np, dtype=torch.float32)
    X_val = torch.tensor(X_val_np, dtype=torch.float32)
    A_train = torch.tensor(A_train_np, dtype=torch.float32)
    A_val = torch.tensor(A_val_np, dtype=torch.float32)
    y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
    y_val = torch.tensor(y_val, dtype=torch.float32).view(-1, 1)
    combined_weight_train = torch.tensor(combined_weight_train, dtype=torch.float32)
    combined_weight_val = torch.tensor(combined_weight_val, dtype=torch.float32)
    
    # Create DataLoaders and train model (same as before)
    train_dataset = TensorDataset(X_train, A_train, combined_weight_train, y_train)
    val_dataset = TensorDataset(X_val, A_val, combined_weight_val, y_val)
    train_loader = DataLoader(train_dataset, batch_size=500, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=500, shuffle=False)
    
    model = RNNCausalModel(
        covariate_dim=4,
        treatment_dim=1,
        hidden_dim=32,
        output_dim=1,
        num_layers=2
    )
    
    tracemalloc.start()
    start_time = time.time()
    model = train_rnn_model(model, train_loader, val_loader)
    end_time = time.time()
    peak_memory = tracemalloc.get_traced_memory()[1]
    tracemalloc.stop()
    
    # Calculate causal effects
    effect_111 = estimate_rnn_causal_effect(model, X_train, A_train, [1,1,1])
    effect_011 = estimate_rnn_causal_effect(model, X_train, A_train, [0,1,1])
    
    return {
        'file_name': os.path.basename(file_path),
        'effect_111': effect_111,
        'effect_011': effect_011,
        'training_time': end_time - start_time,
        'peak_memory': peak_memory / 1024**2
    }

def process_directory(directory_path, output_csv):
    """Process all CSV files in directory and save results"""
    results = []
    processed_files = set()
    
    # Check if output file exists to resume processing
    if os.path.exists(output_csv):
        existing_results = pd.read_csv(output_csv)
        processed_files = set(existing_results['file_name'].tolist())
        results = existing_results.to_dict('records')
    
    # Get all CSV files in directory
    files = [f for f in os.listdir(directory_path) if f.endswith('.csv')]
    
    for i, filename in enumerate(files):
        if filename in processed_files:
            print(f"Skipping already processed file: {filename}")
            continue
            
        file_path = os.path.join(directory_path, filename)
        print(f"Processing file {i+1}/{len(files)}: {filename}")
        
        try:
            result = process_single_file(file_path)
            results.append(result)
            
            # Save after each file in case of interruption
            pd.DataFrame(results).to_csv(output_csv, index=False)
            print(f"Saved results for {filename}")
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
            continue
    
    return pd.DataFrame(results)

# %%
# Main execution
if __name__ == "__main__":
    data_directory = "/home/rl892/miniconda/452final_project/simulation_data/parallel_linear_sd_Z_07_sd_eps_3"
    output_file = "/home/rl892/miniconda/452final_project/simulation_data/small_epoch_parallel_linear_sd_Z_07_sd_eps_3_results_RNN_modified.csv"
    
    print(f"Starting processing of directory: {data_directory}")
    results_df = process_directory(data_directory, output_file)
    print(f"Processing complete. Results saved to {output_file}")
    
    # Print summary statistics
    print("\nSummary Statistics:")
    print(f"Average Effect [1,1,1]: {results_df['effect_111'].mean():.4f}")
    print(f"Average Effect [0,1,1]: {results_df['effect_011'].mean():.4f}")
    print(f"Average Training Time: {results_df['training_time'].mean():.2f} seconds")
    print(f"Average Peak Memory: {results_df['peak_memory'].mean():.2f} MiB")
# Out:
# Starting processing of directory: /home/rl892/miniconda/452final_project/simulation_data/parallel_linear_sd_Z_07_sd_eps_3
# Skipping already processed file: simulated_data_2_seed_20250001_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250002_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250003_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250004_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250005_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250006_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250007_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250008_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250009_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250010_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250011_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250012_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250013_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250014_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250015_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250016_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250017_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250018_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250019_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250020_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250021_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250022_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250023_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250024_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250025_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250026_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250027_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250028_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250029_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250030_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250031_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250032_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250033_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250034_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250035_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250036_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250037_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250038_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250039_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250040_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250041_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250042_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250043_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250044_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250045_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250046_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250047_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250048_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250049_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250050_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250051_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250052_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250053_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250054_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250055_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250056_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250057_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250058_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250059_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250060_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250061_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250062_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250063_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250064_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250065_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250066_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250067_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250068_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250069_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250070_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250071_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250072_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250073_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250074_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250075_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250076_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250077_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250078_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250079_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250080_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250081_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250082_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250083_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250084_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250085_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250086_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250087_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250088_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250089_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250090_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250091_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250092_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250093_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250094_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250095_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250096_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250097_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250098_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250099_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250100_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250101_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250102_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250103_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250104_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250105_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250106_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250107_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250108_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250109_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250110_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250111_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250112_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250113_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250114_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250115_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250116_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250117_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250118_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250119_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250120_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250121_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250122_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250123_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250124_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250125_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250126_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250127_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250128_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250129_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250130_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250131_sdZ_07_sdEps_3.csv
# Skipping already processed file: simulated_data_2_seed_20250132_sdZ_07_sdEps_3.csv
# Processing file 133/1000: simulated_data_2_seed_20250133_sdZ_07_sdEps_3.csv
# Saved results for simulated_data_2_seed_20250133_sdZ_07_sdEps_3.csv
# Processing file 134/1000: simulated_data_2_seed_20250134_sdZ_07_sdEps_3.csv
# Saved results for simulated_data_2_seed_20250134_sdZ_07_sdEps_3.csv
# Processing file 135/1000: simulated_data_2_seed_20250135_sdZ_07_sdEps_3.csv
# Saved results for simulated_data_2_seed_20250135_sdZ_07_sdEps_3.csv
# Processing file 136/1000: simulated_data_2_seed_20250136_sdZ_07_sdEps_3.csv
# Saved results for simulated_data_2_seed_20250136_sdZ_07_sdEps_3.csv
# Processing file 137/1000: simulated_data_2_seed_20250137_sdZ_07_sdEps_3.csv
# Saved results for simulated_data_2_seed_20250137_sdZ_07_sdEps_3.csv
# Processing file 138/1000: simulated_data_2_seed_20250138_sdZ_07_sdEps_3.csv
# Saved results for simulated_data_2_seed_20
sdZ_07_sdEps_3.csv
# Saved results for simulated_data_2_seed_20250999_sdZ_07_sdEps_3.csv
# Processing file 1000/1000: simulated_data_2_seed_20251000_sdZ_07_sdEps_3.csv
# Saved results for simulated_data_2_seed_20251000_sdZ_07_sdEps_3.csv
# Processing complete. Results saved to /home/rl892/miniconda/452final_project/simulation_data/small_epoch_parallel_linear_sd_Z_07_sd_eps_3_results_RNN_modified.csv
#
# Summary Statistics:
# Average Effect [1,1,1]: 4.5265
# Average Effect [0,1,1]: 3.1149
# Average Training Time: 7.17 seconds
# Average Peak Memory: 0.63 MiB

# %%
import pandas as pd
import numpy as np

def calculate_metrics(csv_path, true_effect_111, true_effect_011):
    """
    Calculate performance metrics for causal effect estimates
    
    Args:
        csv_path: Path to results CSV file
        true_effect_111: True causal effect for [1,1,1] vs [0,0,0]
        true_effect_011: True causal effect for [0,1,1] vs [0,0,0]
    
    Returns:
        Dictionary containing all six metrics
    """
    # Read results
    df = pd.read_csv(csv_path)
    
    # Calculate metrics for effect_111
    mean_hat_111 = df['effect_111'].mean()
    rel_bias_111 = (mean_hat_111 - true_effect_111) / true_effect_111
    mcsd_111 = df['effect_111'].std(ddof=1)  # Using H-1 in denominator
    rmse_111 = np.sqrt(((df['effect_111'] - true_effect_111)**2).mean())
    
    # Calculate metrics for effect_011
    mean_hat_011 = df['effect_011'].mean()
    rel_bias_011 = (mean_hat_011 - true_effect_011) / true_effect_011
    mcsd_011 = df['effect_011'].std(ddof=1)  # Using H-1 in denominator
    rmse_011 = np.sqrt(((df['effect_011'] - true_effect_011)**2).mean())
    
    return {
        'effect_111': {
            'relative_bias': rel_bias_111,
            'mcsd': mcsd_111,
            'rmse': rmse_111
        },
        'effect_011': {
            'relative_bias': rel_bias_011,
            'mcsd': mcsd_011,
            'rmse': rmse_011
        }
    }

# Example usage
if __name__ == "__main__":
    results_csv = "/home/rl892/miniconda/452final_project/simulation_data/small_epoch_parallel_linear_sd_Z_07_sd_eps_3_results_RNN_modified.csv"

        
    # You'll need to provide these true effect values from your large simulation
    true_effect_111 = 5.041  # Replace with your actual value
    true_effect_011 = 3.021  # Replace with your actual value
    
    metrics = calculate_metrics(results_csv, 5.041, 3.021)
    
    # Print results
    print("Performance Metrics:")
    print("\nFor Effect [1,1,1] vs [0,0,0]:")
    print(f"Relative Bias: {metrics['effect_111']['relative_bias']:.4f}")
    print(f"Monte Carlo SD: {metrics['effect_111']['mcsd']:.4f}")
    print(f"RMSE: {metrics['effect_111']['rmse']:.4f}")
    
    print("\nFor Effect [0,1,1] vs [0,0,0]:")
    print(f"Relative Bias: {metrics['effect_011']['relative_bias']:.4f}")
    print(f"Monte Carlo SD: {metrics['effect_011']['mcsd']:.4f}")
    print(f"RMSE: {metrics['effect_011']['rmse']:.4f}")
# Out:
# Performance Metrics:
#
# For Effect [1,1,1] vs [0,0,0]:
# Relative Bias: -0.1021
# Monte Carlo SD: 1.4433
# RMSE: 1.5316
#
# For Effect [0,1,1] vs [0,0,0]:
# Relative Bias: 0.0311
# Monte Carlo SD: 1.1944
# RMSE: 1.1975

# %%
import pandas as pd

# Load the CSV file
results_df = pd.read_csv("/home/rl892/miniconda/452final_project/simulation_data/small_epoch_parallel_linear_sd_Z_07_sd_eps_3_results_RNN_modified.csv")

# Preview the first 10 lines
print(results_df.head(20))

print(results_df.shape)
